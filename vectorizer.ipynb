# %%
import glob
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
X_train = pd.read_csv('Datasets/IMDb_train.csv')
y_train = pd.read_csv('Datasets/y_train.csv')
X_test = pd.read_csv('Datasets/IMDb_test.csv')
y_test = pd.read_csv('Datasets/y_test.csv')
target_names = y_test.columns.values

# %%
def file_list(X):

    base_directory = 'Datasets/*'
    l = []

    for description in X['IMDb description']:
        pattern = os.path.join(base_directory, '*', description)
        for file_path in glob.iglob(pattern, recursive=True):
            l.append(file_path)
            
    print(l)
    return l

# %%
def test_fit(X, vectorizer):
    files = file_list(X)
    vectorizer.fit(open(filename).read() for filename in files)
    vector = vectorizer.transform((open(filename).read() for filename in files))
    return vector

# %%
vectorizer = TfidfVectorizer(ngram_range = (1,2), max_features = 1000, norm = 'l2', sublinear_tf= True)

# %%
cleaned = pd.read_csv('Datasets/cleaned.csv')

# %%
print(test_fit(cleaned, vectorizer))
# Out:
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(test_fit(cleaned, vectorizer))
#
# Cell In[18], line 3, in test_fit(X, vectorizer)
#       1 def test_fit(X, vectorizer):
#       2     files = file_list(X)
# ----> 3     vectorizer.fit(open(filename).read() for filename in files)
#       4     vector = vectorizer.transform((open(filename).read() for filename in files))
#       5     return vector
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_extraction\text.py:2061, in TfidfVectorizer.fit(self, raw_documents, y)
#    2054 self._warn_for_unused_params()
#    2055 self._tfidf = TfidfTransformer(
#    2056     norm=self.norm,
#    2057     use_idf=self.use_idf,
#    2058     smooth_idf=self.smooth_idf,
#    2059     sublinear_tf=self.sublinear_tf,
#    2060 )
# -> 2061 X = super().fit_transform(raw_documents)
#    2062 self._tfidf.fit(X)
#    2063 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_extraction\text.py:1372, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1364             warnings.warn(
#    1365                 "Upper case characters found in"
#    1366                 " vocabulary while 'lowercase'"
#    1367                 " is True. These entries will not"
#    1368                 " be matched with any documents"
#    1369             )
#    1370             break
# -> 1372 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1374 if self.binary:
#    1375     X.data.fill(1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_extraction\text.py:1278, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1276     vocabulary = dict(vocabulary)
#    1277     if not vocabulary:
# -> 1278         raise ValueError(
#    1279             "empty vocabulary; perhaps the documents only contain stop words"
#    1280         )
#    1282 if indptr[-1] > np.iinfo(np.int32).max:  # = 2**31 - 1
#    1283     if _IS_32BIT:
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words
