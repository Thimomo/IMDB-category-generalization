# %%
import glob
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
X_train = pd.read_csv('Datasets/IMDb_train.csv') # Input features
y_train = pd.read_csv('Datasets/y_train.csv') # Target 

X_test = pd.read_csv('Datasets/IMDb_test.csv')
y_test = pd.read_csv('Datasets/y_test.csv')

target_names = y_test.columns.values

# %%
def file_list(X):

    base_directory = 'Datasets/*'
    l = []

    for description in X['IMDb description']:
        pattern = os.path.join(base_directory, '*', description)
        for file_path in glob.iglob(pattern, recursive=True):
            l.append(file_path)
            
    print(l)
    return l

# %%
def test_fit(X, vectorizer):
    files = file_list(X)
    vectorizer.fit(open(filename).read() for filename in files)
    vector = vectorizer.transform((open(filename).read() for filename in files))
    return vector

# %%
vectorizer = TfidfVectorizer(ngram_range = (1,2), max_features = 1000, norm = 'l2', sublinear_tf= True)

# %%
cleaned = pd.read_csv('Datasets/cleaned.csv')

# %%
print(test_fit(cleaned, vectorizer))
# Out:
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(test_fit(cleaned, vectorizer))
#
# Cell In[12], line 3, in test_fit(X, vectorizer)
#       1 def test_fit(X, vectorizer):
#       2     files = file_list(X)
# ----> 3     vectorizer.fit(open(filename).read() for filename in files)
#       4     vector = vectorizer.transform((open(filename).read() for filename in files))
#       5     return vector
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/feature_extraction/text.py:2074, in TfidfVectorizer.fit(self, raw_documents, y)
#    2067 self._warn_for_unused_params()
#    2068 self._tfidf = TfidfTransformer(
#    2069     norm=self.norm,
#    2070     use_idf=self.use_idf,
#    2071     smooth_idf=self.smooth_idf,
#    2072     sublinear_tf=self.sublinear_tf,
#    2073 )
# -> 2074 X = super().fit_transform(raw_documents)
#    2075 self._tfidf.fit(X)
#    2076 return self
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/feature_extraction/text.py:1376, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1368             warnings.warn(
#    1369                 "Upper case characters found in"
#    1370                 " vocabulary while 'lowercase'"
#    1371                 " is True. These entries will not"
#    1372                 " be matched with any documents"
#    1373             )
#    1374             break
# -> 1376 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1378 if self.binary:
#    1379     X.data.fill(1)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/feature_extraction/text.py:1282, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1280     vocabulary = dict(vocabulary)
#    1281     if not vocabulary:
# -> 1282         raise ValueError(
#    1283             "empty vocabulary; perhaps the documents only contain stop words"
#    1284         )
#    1286 if indptr[-1] > np.iinfo(np.int32).max:  # = 2**31 - 1
#    1287     if _IS_32BIT:
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words
